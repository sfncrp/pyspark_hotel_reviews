# %%
import toLog
log = toLog.log('Categories extraction starting')

# %%
from pprint import pprint

# %%
from pyspark.sql import SparkSession

spark = (SparkSession.builder
         .appName('Python spark')
         .config('spark.some.config.option','some-value')
         .getOrCreate()
         )

# %%
# read file from hdfs and infer schema
df_cleaned = spark.read.csv("hdfs://masterbig-1.itc.unipi.it:54310/user/student18/df_cleaned.csv", header = True, inferSchema = True)
df_cleaned.count()
# Out:
# 505009

# %%
from pyspark.mllib.feature import Word2Vec

# %%
rdd_tokens = (df_cleaned.select("Review").rdd
              #.sample(False,0.5)
              .filter(lambda x: x['Review'] is not None)
              .map(lambda x: x['Review'].split(" "))
             )

# %%
word2Vec = Word2Vec().setMinCount(50).setVectorSize(300).setWindowSize(5)

# %%
model = word2Vec.fit(rdd_tokens)

# %%
categories = ['breakfast', 'facilities', 'staff', 'room', 'internet', 'location', 'bathroom', 'food']
#food(breakfast), #staff(service), #room, #internet(wi-fi), #location, #bath

# %%
all_categories = {cat:dict(model.findSynonyms(cat, num = 20)) for cat in categories}

# %%
pprint(all_categories)
# Out:
# {'bathroom': {'bathroom.': 0.522175820356142,
#               'bathrooms': 0.5087266509978882,
#               'bathtub': 0.5177911604143423,
#               'cubicle': 0.5217659655658738,
#               'ensuite': 0.5783865873193351,
#               'fixture': 0.5384696203033031,
#               'flooring': 0.5159286619522134,
#               'grouting': 0.5377989416292231,
#               'leaky': 0.4985537406377214,
#               'restroom': 0.5182082354147269,
#               'rusty': 0.5091987232634079,
#               'shower': 0.5137119930417334,
#               'showerhead': 0.546583679180073,
#               'stall': 0.5118656945649197,
#               'toilet': 0.5028246081334126,
#               'toilette': 0.5177291923428092,
#               'washbasin': 0.5583851326054067,
#               'washroom': 0.6306056857556726,
#               'wc': 0.6125714696608704,
#               'wobbly': 0.5305512987867597},
#  'breakfast': {'assortment': 0.3352828189113468,
#                'beakfast': 0.4665915505150366,
#                'bfast': 0.5329819153651842,
#                'brakfast': 0.43719417043841746,
#                'breackfast': 0.5577834714624417,
#                'breafast': 0.5236530159058473,
#                'breakfast.': 0.5066281678923651,
#                'breakfasts': 0.5903444419133451,
#                'breakfeast': 0.38156897384362076,
#                'breakfest': 0.5611895191580788,
#                'brekfast': 0.5509522963443744,
#                'brekkie': 0.5633648099578001,
#                'carvery': 0.38382654441677916,
#                'comprehensive': 0.33840572885805204,
#                'diverse': 0.34021281750193805,
#                'food': 0.4599208821563037,
#                'food.': 0.38377566048581274,
#                'resteraunt': 0.3499279961434182,
#                'sevice': 0.3258024019021257,
#                'varied': 0.36282001727356034},
#  'facilities': {'amenities': 0.47315205392743376,
#                 'ammenities': 0.44036439342322464,
#                 'appointments': 0.4172849052366503,
#                 'coffee.': 0.34604907654351064,
#                 'conveniences': 0.348304586181626,
#                 'equipment': 0.47779787348286124,
#                 'equipments': 0.34273169799640146,
#                 'facilites': 0.5994251693627115,
#                 'facilities.': 0.6315603356789444,
#                 'facility': 0.7124044251684359,
#                 'facility.': 0.49176387396421406,
#                 'facilties': 0.6079490850291257,
#                 'machine.': 0.34858139567226354,
#                 'maker': 0.3593856889544792,
#                 'massages': 0.36266311964953374,
#                 'services': 0.34823718549038557,
#                 'spa.': 0.3423044576933015,
#                 'supplies': 0.3626999148022627,
#                 'tee': 0.3579214666822858,
#                 'treatments': 0.3973297401697186},
#  'food': {'bistro': 0.49332150450515977,
#           'brasserie': 0.47616380938020303,
#           'breakfast': 0.45992079795942536,
#           'carvery': 0.534367078210509,
#           'dinner.': 0.4625421346587395,
#           'food.': 0.5191015230815695,
#           'foods': 0.4934398893593045,
#           'grill': 0.4854240567654114,
#           'meals': 0.5493989631160734,
#           'menu': 0.4780953158967237,
#           'menu.': 0.4929075506059728,
#           'menus': 0.4529035833612889,
#           'presentation': 0.461300424746453,
#           'resteraunt': 0.4885755562369201,
#           'resturant': 0.46376340713453296,
#           'seafood': 0.522923344188036,
#           'selections': 0.4637956172306709,
#           'steak': 0.4935267496913269,
#           'sushi': 0.5104430794244638,
#           'wines': 0.5334279166465663},
#  'internet': {'3g': 0.5391914631299881,
#               '4g': 0.5457697172913051,
#               'connection': 0.5671137475951055,
#               'connection.': 0.5038783419523116,
#               'coverage': 0.5826543340132705,
#               'intermittent': 0.5398588946651893,
#               'internet.': 0.5386092787731523,
#               'network': 0.500710819526192,
#               'reliable': 0.5276893759424726,
#               'signal': 0.5435724148159325,
#               'signal.': 0.5179319459542001,
#               'speed': 0.5604959810522551,
#               'stable': 0.5832969442261877,
#               'unreliable': 0.5176874375238149,
#               'unstable': 0.5557025113414088,
#               'wi': 0.5160916147910617,
#               'wifi': 0.8240687046685938,
#               'wifi.': 0.5236569678101572,
#               'wireless': 0.665060246799018,
#               'wlan': 0.5272357649200385},
#  'location': {'awsome': 0.3462247907844279,
#               'brakfast': 0.35458439013963666,
#               'breackfast': 0.3280525724640477,
#               'breakfest': 0.3415809508866276,
#               'cleanless': 0.330126880153729,
#               'everthing': 0.3508542845278863,
#               'excelent': 0.32228003565209157,
#               'excelente': 0.37203381469048186,
#               'exelent': 0.3301818223822537,
#               'frendly': 0.3500848621200604,
#               'grate': 0.34088675834366544,
#               'lication': 0.616638335968867,
#               'localisation': 0.5615478618852244,
#               'locality': 0.4476050049199967,
#               'localization': 0.6323955393334093,
#               'location.': 0.339734217151291,
#               'locations': 0.3681206615550167,
#               'position': 0.7310900376553153,
#               'unbeatable': 0.32875366197456907,
#               'wonderfull': 0.32848086559240675},
#  'room': {'apartment': 0.3070585969834851,
#           'appartment': 0.30170587448476105,
#           'awfull': 0.2926676492304301,
#           'bathroom': 0.2813745673993046,
#           'bathtube': 0.2936045635235582,
#           'bedroom': 0.579012960433045,
#           'bedroom.': 0.32801561957118514,
#           'bedrooms': 0.315376993496398,
#           'ensuite': 0.32758896112617014,
#           'rm': 0.40286191745509753,
#           'rom': 0.4963240887097971,
#           'room.': 0.4128838021659973,
#           'rooms': 0.4198492677703006,
#           'rooms.': 0.28211102334787436,
#           'rooom': 0.4664969777712628,
#           'studio': 0.28421731484545554,
#           'suite': 0.2751918771806063,
#           'suite.': 0.2987631763399653,
#           'toilette': 0.26033970300779485,
#           'washroom': 0.26248339217006417},
#  'staff': {'approachable': 0.4838916237311654,
#            'chatty': 0.4628017769999767,
#            'conceirge': 0.4572972891271127,
#            'concierges': 0.5566385005873299,
#            'crew': 0.5072383045575386,
#            'doormen': 0.5064394728567507,
#            'employees': 0.6326107729508442,
#            'hospitable': 0.47159674043482436,
#            'hosts': 0.48752852329354834,
#            'personel': 0.5079747610468901,
#            'personell': 0.5414581096925634,
#            'personnel': 0.597640339852691,
#            'porters': 0.480371059567041,
#            'receptionists': 0.6121186601962139,
#            'respectful': 0.4627337316942394,
#            'staf': 0.6144660814727833,
#            'stafff': 0.5745849843723161,
#            'staffs': 0.6434688556625778,
#            'stuff': 0.5591239946359977,
#            'team': 0.5234207288877143}}

# %%
merged = {cat: [] for cat in categories}

# %% [markdown]
# ### cleaning word2vec categories

# %%
for cat, features in all_categories.items():
    print("macro categoria: ", cat)
    print(".........")
    for feature in features.keys():
        print(feature)
        answer = input('inserisci feature? y/n: ')
        if answer == 'y':
            merged[cat].append(feature)
# Out:
# macro categoria:  staff
# .........
# personnel
# inserisci feature? y/n: y
# doormen
# inserisci feature? y/n: y
# personel
# inserisci feature? y/n: y
# concierges
# inserisci feature? y/n: y
# approachable
# inserisci feature? y/n:
# stafff
# inserisci feature? y/n: y
# respectful
# inserisci feature? y/n: n
# employees
# inserisci feature? y/n: y
# hosts
# inserisci feature? y/n: y
# team
# inserisci feature? y/n: y
# staffs
# inserisci feature? y/n: y
# receptionists
# inserisci feature? y/n: y
# stuff
# inserisci feature? y/n: n
# hospitable
# inserisci feature? y/n: y
# staf
# inserisci feature? y/n: y
# chatty
# inserisci feature? y/n: n
# personell
# inserisci feature? y/n: y
# porters
# inserisci feature? y/n: y
# conceirge
# inserisci feature? y/n: y
# crew
# inserisci feature? y/n: y
# macro categoria:  room
# .........
# washroom
# inserisci feature? y/n: n
# suite
# inserisci feature? y/n: y
# studio
# inserisci feature? y/n: y
# room.
# inserisci feature? y/n: y
# rooms
# inserisci feature? y/n: y
# awfull
# inserisci feature? y/n: n
# appartment
# inserisci feature? y/n: y
# apartment
# inserisci feature? y/n: y
# bathtube
# inserisci feature? y/n: n
# rooom
# inserisci feature? y/n: y
# bedroom.
# inserisci feature? y/n: y
# toilette
# inserisci feature? y/n: n
# bedroom
# inserisci feature? y/n: y
# rm
# inserisci feature? y/n: n
# rom
# inserisci feature? y/n: y
# bathroom
# inserisci feature? y/n: n
# bedrooms
# inserisci feature? y/n: y
# rooms.
# inserisci feature? y/n: y
# ensuite
# inserisci feature? y/n: n
# suite.
# inserisci feature? y/n: y
# macro categoria:  location
# .........
# unbeatable
# inserisci feature? y/n: n
# everthing
# inserisci feature? y/n: n
# excelente
# inserisci feature? y/n: n
# position
# inserisci feature? y/n: y
# wonderfull
# inserisci feature? y/n: n
# breakfest
# inserisci feature? y/n: n
# lication
# inserisci feature? y/n: y
# locations
# inserisci feature? y/n: y
# brakfast
# inserisci feature? y/n: n
# location.
# inserisci feature? y/n: y
# grate
# inserisci feature? y/n: n
# locality
# inserisci feature? y/n: y
# excelent
# inserisci feature? y/n: n
# cleanless
# inserisci feature? y/n: n
# localisation
# inserisci feature? y/n: y
# breackfast
# inserisci feature? y/n: n
# exelent
# inserisci feature? y/n: n
# awsome
# inserisci feature? y/n: n
# localization
# inserisci feature? y/n: y
# frendly
# inserisci feature? y/n: n
# macro categoria:  facilities
# .........
# tee
# inserisci feature? y/n: n
# facilites
# inserisci feature? y/n: y
# facility
# inserisci feature? y/n: y
# maker
# inserisci feature? y/n: n
# supplies
# inserisci feature? y/n: y
# treatments
# inserisci feature? y/n: n
# facilties
# inserisci feature? y/n: y
# equipment
# inserisci feature? y/n: y
# services
# inserisci feature? y/n: n
# facility.
# inserisci feature? y/n: y
# equipments
# inserisci feature? y/n: y
# machine.
# inserisci feature? y/n: n
# spa.
# inserisci feature? y/n: y
# ammenities
# inserisci feature? y/n: y
# facilities.
# inserisci feature? y/n: y
# amenities
# inserisci feature? y/n: y
# conveniences
# inserisci feature? y/n: n
# coffee.
# inserisci feature? y/n: n
# massages
# inserisci feature? y/n: y
# appointments
# inserisci feature? y/n: n
# macro categoria:  bathroom
# .........
# toilet
# inserisci feature? y/n: y
# grouting
# inserisci feature? y/n: n
# washroom
# inserisci feature? y/n: y
# flooring
# inserisci feature? y/n: n
# leaky
# inserisci feature? y/n: n
# stall
# inserisci feature? y/n: n
# rusty
# inserisci feature? y/n: n
# bathroom.
# inserisci feature? y/n: y
# washbasin
# inserisci feature? y/n: y
# fixture
# inserisci feature? y/n: y
# wobbly
# inserisci feature? y/n: n
# wc
# inserisci feature? y/n: y
# shower
# inserisci feature? y/n: y
# restroom
# inserisci feature? y/n: y
# showerhead
# inserisci feature? y/n: y
# toilette
# inserisci feature? y/n: y
# bathtub
# inserisci feature? y/n: y
# cubicle
# inserisci feature? y/n: y
# bathrooms
# inserisci feature? y/n: y
# ensuite
# inserisci feature? y/n: y
# macro categoria:  internet
# .........
# wi
# inserisci feature? y/n: n
# signal
# inserisci feature? y/n: y
# reliable
# inserisci feature? y/n: n
# speed
# inserisci feature? y/n: y
# wlan
# inserisci feature? y/n: y
# internet.
# inserisci feature? y/n: y
# network
# inserisci feature? y/n: y
# unreliable
# inserisci feature? y/n: n
# 3g
# inserisci feature? y/n: y
# signal.
# inserisci feature? y/n: y
# wifi.
# inserisci feature? y/n: y
# intermittent
# inserisci feature? y/n: n
# stable
# inserisci feature? y/n: n
# connection.
# inserisci feature? y/n: y
# 4g
# inserisci feature? y/n: y
# wireless
# inserisci feature? y/n: y
# connection
# inserisci feature? y/n: y
# coverage
# inserisci feature? y/n: y
# unstable
# inserisci feature? y/n: n
# wifi
# inserisci feature? y/n: y
# macro categoria:  breakfast
# .........
# bfast
# inserisci feature? y/n: y
# food.
# inserisci feature? y/n:
# varied
# inserisci feature? y/n: n
# breakfest
# inserisci feature? y/n: y
# resteraunt
# inserisci feature? y/n: y
# sevice
# inserisci feature? y/n: n
# assortment
# inserisci feature? y/n: y
# breakfeast
# inserisci feature? y/n: y
# breafast
# inserisci feature? y/n: y
# breakfast.
# inserisci feature? y/n: y
# food
# inserisci feature? y/n: y
# brekkie
# inserisci feature? y/n: y
# brekfast
# inserisci feature? y/n: y
# breakfasts
# inserisci feature? y/n: y
# comprehensive
# inserisci feature? y/n: n
# breackfast
# inserisci feature? y/n: y
# diverse
# inserisci feature? y/n: n
# beakfast
# inserisci feature? y/n: y
# carvery
# inserisci feature? y/n:
# brakfast
# inserisci feature? y/n: y
# macro categoria:  food
# .........
# wines
# inserisci feature? y/n: y
# grill
# inserisci feature? y/n: y
# food.
# inserisci feature? y/n: y
# meals
# inserisci feature? y/n: y
# menus
# inserisci feature? y/n: y
# sushi
# inserisci feature? y/n: y
# seafood
# inserisci feature? y/n: y
# menu
# inserisci feature? y/n: y
# foods
# inserisci feature? y/n: y
# breakfast
# inserisci feature? y/n: y
# resturant
# inserisci feature? y/n: y
# resteraunt
# inserisci feature? y/n: y
# steak
# inserisci feature? y/n: y
# dinner.
# inserisci feature? y/n: y
# bistro
# inserisci feature? y/n: y
# selections
# inserisci feature? y/n: y
# menu.
# inserisci feature? y/n: y
# presentation
# inserisci feature? y/n: y
# carvery
# inserisci feature? y/n: y
# brasserie
# inserisci feature? y/n: y

# %%
merged
# Out:
# {'bathroom': ['toilet',
#   'washroom',
#   'bathroom.',
#   'washbasin',
#   'fixture',
#   'wc',
#   'shower',
#   'restroom',
#   'showerhead',
#   'toilette',
#   'bathtub',
#   'cubicle',
#   'bathrooms',
#   'ensuite'],
#  'breakfast': ['bfast',
#   'breakfest',
#   'resteraunt',
#   'assortment',
#   'breakfeast',
#   'breafast',
#   'breakfast.',
#   'food',
#   'brekkie',
#   'brekfast',
#   'breakfasts',
#   'breackfast',
#   'beakfast',
#   'brakfast'],
#  'facilities': ['facilites',
#   'facility',
#   'supplies',
#   'facilties',
#   'equipment',
#   'facility.',
#   'equipments',
#   'spa.',
#   'ammenities',
#   'facilities.',
#   'amenities',
#   'massages'],
#  'food': ['wines',
#   'grill',
#   'food.',
#   'meals',
#   'menus',
#   'sushi',
#   'seafood',
#   'menu',
#   'foods',
#   'breakfast',
#   'resturant',
#   'resteraunt',
#   'steak',
#   'dinner.',
#   'bistro',
#   'selections',
#   'menu.',
#   'presentation',
#   'carvery',
#   'brasserie'],
#  'internet': ['signal',
#   'speed',
#   'wlan',
#   'internet.',
#   'network',
#   '3g',
#   'signal.',
#   'wifi.',
#   'connection.',
#   '4g',
#   'wireless',
#   'connection',
#   'coverage',
#   'wifi'],
#  'location': ['position',
#   'lication',
#   'locations',
#   'location.',
#   'locality',
#   'localisation',
#   'localization'],
#  'room': ['suite',
#   'studio',
#   'room.',
#   'rooms',
#   'appartment',
#   'apartment',
#   'rooom',
#   'bedroom.',
#   'bedroom',
#   'rom',
#   'bedrooms',
#   'rooms.',
#   'suite.'],
#  'staff': ['personnel',
#   'personnel',
#   'doormen',
#   'personel',
#   'concierges',
#   'stafff',
#   'employees',
#   'hosts',
#   'team',
#   'staffs',
#   'receptionists',
#   'hospitable',
#   'staf',
#   'personell',
#   'porters',
#   'conceirge',
#   'crew']}

# %%
# Out:
# {'bathroom': ['toilet',
#   'washroom',
#   'bathroom.',
#   'washbasin',
#   'fixture',
#   'wc',
#   'shower',
#   'restroom',
#   'showerhead',
#   'toilette',
#   'bathtub',
#   'cubicle',
#   'bathrooms',
#   'ensuite'],
#  'breakfast': ['bfast',
#   'breakfest',
#   'resteraunt',
#   'assortment',
#   'breakfeast',
#   'breafast',
#   'breakfast.',
#   'food',
#   'brekkie',
#   'brekfast',
#   'breakfasts',
#   'breackfast',
#   'beakfast',
#   'brakfast'],
#  'facilities': ['facilites',
#   'facility',
#   'supplies',
#   'facilties',
#   'equipment',
#   'facility.',
#   'equipments',
#   'spa.',
#   'ammenities',
#   'facilities.',
#   'amenities',
#   'massages'],
#  'food': ['wines',
#   'grill',
#   'food.',
#   'meals',
#   'menus',
#   'sushi',
#   'seafood',
#   'menu',
#   'foods',
#   'breakfast',
#   'resturant',
#   'resteraunt',
#   'steak',
#   'dinner.',
#   'bistro',
#   'selections',
#   'menu.',
#   'presentation',
#   'carvery',
#   'brasserie'],
#  'internet': ['signal',
#   'speed',
#   'wlan',
#   'internet.',
#   'network',
#   '3g',
#   'signal.',
#   'wifi.',
#   'connection.',
#   '4g',
#   'wireless',
#   'connection',
#   'coverage',
#   'wifi'],
#  'location': ['position',
#   'lication',
#   'locations',
#   'location.',
#   'locality',
#   'localisation',
#   'localization'],
#  'room': ['suite',
#   'studio',
#   'room.',
#   'rooms',
#   'appartment',
#   'apartment',
#   'rooom',
#   'bedroom.',
#   'bedroom',
#   'rom',
#   'bedrooms',
#   'rooms.',
#   'suite.'],
#  'staff': ['personnel',
#   'personnel',
#   'doormen',
#   'personel',
#   'concierges',
#   'stafff',
#   'employees',
#   'hosts',
#   'team',
#   'staffs',
#   'receptionists',
#   'hospitable',
#   'staf',
#   'personell',
#   'porters',
#   'conceirge',
#   'crew']}

# %% [markdown]
# ### categories word2vec scritte sul file
